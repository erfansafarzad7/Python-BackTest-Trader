# %%
import datetime

import numpy as np
import pandas as pd
from talib import abstract

import warnings
warnings.filterwarnings('ignore')


SMA = abstract.SMA

# %%
def load_data(file_path):
    data = pd.read_csv(file_path)
    # data['Close'] = data['Price']
    data['Open'] = data['Open']
    data['Close'] = data['Close']
    data['High'] = data['High']
    data['Low'] = data['Low']
    return data

# %%
# Load historical market data
data = load_data("data2.csv")
data.head()
# Out:
#                   Date   Open   High    Low  Close
# 0  2000-01-01 00:00:00  36063  69908  60628  67354
# 1  2000-01-02 00:00:00  48763  29568  18146  87904
# 2  2000-01-03 00:00:00  37359  99678   8815  65351
# 3  2000-01-04 00:00:00  60449   8657  47729  67330
# 4  2000-01-05 00:00:00  21278  99803  85125  76529

# %%
from abc import ABC, abstractmethod


class Strategy(ABC):

    def __init__(self):
        pass
    
    @abstractmethod
    def generate_signal(self, data):
        pass

# %%
class SMAStrategy(Strategy):
    def __init__(self, short_window, long_window, sl, tp1, tp2, tp3):
        super().__init__()
        self.short_window = short_window
        self.long_window = long_window
        self.stop_loss = sl
        self.take_profit1 = tp1
        self.take_profit2 = tp2
        self.take_profit3 = tp3

    #####################################################################################################
    # Signal
    #####################################################################################################

    def generate_signal(self, data):
        signals = pd.Series(index=data.index, dtype='int')

        data['Short_MA'] = SMA(data, timeperiod=self.short_window, price='Open')
        data['Long_MA'] = SMA(data, timeperiod=self.long_window, price='Open')

        # Buy signal
        buy_signal = (data['Short_MA'] > data['Long_MA']) #& (signals.shift(1) != 1)
        signals[buy_signal] = 1

        # Sell signal
        sell_signal = (data['Short_MA'] < data['Long_MA']) #& (signals.shift(1) != -1)
        signals[sell_signal] = -1
        
    #####################################################################################################
    # Set Stoploss TakeProfit
    #####################################################################################################

        # Apply stop-loss and take-profit
        data['Signal'] = signals
        data['Sl'] = np.where(signals == 1, data['Open'] * (1 - self.stop_loss), data['Open'] * (1 + self.stop_loss))
        data['Tp1'] = np.where(signals == 1, data['Open'] * (1 + self.take_profit1), data['Open'] * (1 - self.take_profit1))
        data['Tp2'] = np.where(signals == 1, data['Open'] * (1 + self.take_profit2), data['Open'] * (1 - self.take_profit2))
        data['Tp3'] = np.where(signals == 1, data['Open'] * (1 + self.take_profit3), data['Open'] * (1 - self.take_profit3))

        # data = data.drop(['Short_MA', 'Long_MA', "Vol.", "Change %", "Price"], axis=1)
        data = data.dropna()
        return data

sma_strategy = SMAStrategy(2, 5, 0.05, 0.01, 0.015, 0.02)
generated_signals = sma_strategy.generate_signal(data)

generated_signals
# Out:
#                     Date   Open   High    Low  Close  Short_MA  Long_MA  \
# 4    2000-01-05 00:00:00  21278  99803  85125  76529   40863.5  40782.4
# 5    2000-01-06 00:00:00  44945  64440  24247  46338   33111.5  42558.8
# 6    2000-01-07 00:00:00   1525  81761  48916  20722   23235.0  33111.2
# 7    2000-01-08 00:00:00  20509  93595  40083  85981   11017.0  29741.2
# 8    2000-01-09 00:00:00  59570  24327  19537  78719   40039.5  29565.4
# ..                   ...    ...    ...    ...    ...       ...      ...
# 711  2001-12-12 00:00:00  27922  34842  67733  15546   54954.0  50971.2
# 712  2001-12-13 00:00:00  58434  83204  29400  52950   43178.0  53662.0
# 713  2001-12-14 00:00:00  34692  27357  58721  47724   46563.0  44696.0
# 714  2001-12-15 00:00:00  69499  78422  25578  82906   52095.5  54506.6
# 715  2001-12-16 00:00:00  89306  81806  80205  62379   79402.5  55970.6
#
#      Signal        Sl       Tp1        Tp2       Tp3
# 4       1.0  20214.10  21490.78  21597.170  21703.56
# 5      -1.0  47192.25  44495.55  44270.825  44046.10
# 6      -1.0   1601.25   1509.75   1502.125   1494.50
# 7      -1.0  21534.45  20303.91  20201.365  20098.82
# 8       1.0  56591.50  60165.70  60463.550  60761.40
# ..      ...       ...       ...        ...       ...
# 711     1.0  26525.90  28201.22  28340.830  28480.44
# 712    -1.0  61355.70  57849.66  57557.490  57265.32
# 713     1.0  32957.40  35038.92  35212.380  35385.84
# 714    -1.0  72973.95  68804.01  68456.515  68109.02
# 715     1.0  84840.70  90199.06  90645.590  91092.12
#
# [712 rows x 12 columns]

# %% [markdown]
# # First Version on Main Function

# %%
trade_log = pd.DataFrame(columns=['Open DateTime', 'Open Price', 
                                  'Close DateTime', 'Close Price',
                                  'Direction',
                                  'Leverage', 
                                  'Margin', 
                                  'Result',
                                  'Profit Loss Percentage', 
                                  'profit Loss Amount',
                                  ]
                         )


def open_position(direction, open_price, leverage, margin):
    global trade_log
    print('Balance Management')
    
    print('open **********************', direction, open_price, leverage, margin)
    
    open_datetime = datetime.datetime.now()
    
    # New row
    trade_log.loc[len(trade_log)] = [open_datetime, open_price, 0, 0, direction, leverage, margin, 'None', 0, 0]
    

    
def close_position(close_price):
    global trade_log
    
    print('close **********************', close_price)
    
    # Update last row
    close_datetime = datetime.datetime.now()
    
    trade_log['Close DateTime'].iloc[-1] = close_datetime
    trade_log['Close Price'].iloc[-1] = close_price
    
    # Calculate Profit
    calculate_profit_loss()
    


def calculate_profit_loss():
    global trade_log
    
    # calculate last row
    open_price = trade_log['Open Price'].iloc[-1]
    close_price = trade_log['Close Price'].iloc[-1]
    direction = trade_log['Direction'].iloc[-1]
    leverage = trade_log['Leverage'].iloc[-1]
    margin = trade_log['Margin'].iloc[-1]
    
    
    print('calculate *****************', open_price, close_price, direction, leverage, margin)
    
        
    if direction == 'long':
        result = close_price - open_price
    elif direction == 'short':
        result = open_price - close_price
    else:
        raise ValueError("Invalid transaction type. Must be 'long' or 'short'.")
    
    profit_loss_percentage = (result / open_price) * 100
    profit_loss_amount = result * margin * leverage
    
    if result > 0:
        profit_loss_status = 'profit'
    else:
        profit_loss_status = 'loss'
    

    trade_log['Result'].iloc[-1] = profit_loss_status
    trade_log['Profit Loss Percentage'].iloc[-1] = profit_loss_percentage
    trade_log['profit Loss Amount'].iloc[-1] = profit_loss_amount
    


trade_log
# Out:
# Empty DataFrame
# Columns: [Open DateTime, Open Price, Close DateTime, Close Price, Direction, Leverage, Margin, Result, Profit Loss Percentage, profit Loss Amount]
# Index: []

# %%
history = pd.DataFrame(columns=['Direction', 'Sl', 'Tp1', 'Tp2', 'Tp3', 'Status'])
history.loc[0] = [0, 0, 0, 0, 0, 'None']

current_position = 0
previous_position = 0


def check_tp_sl(new_data):
    global history, current_position
    
    sl = history['Sl'].iloc[-1]
    tp1 = history['Tp1'].iloc[-1]
    tp2 = history['Tp2'].iloc[-1]
    tp3 = history['Tp3'].iloc[-1]
    
    low = new_data['Low']
    high = new_data['High']
    
    
    if current_position == 1:
        if low < sl :
            print('low ', low,' sl', sl)
            print("SL Active Long")
            
            close_position(sl)
            
            return 1, 'loss'
        
        if high > tp1 or high > tp2  or high > tp3:
            print('high ', high, ' tp ', tp1, tp2, tp3)
            print("TP Active Long")
            


            if high > tp3 and high > tp2 and high > tp3:
                close_position(tp3)
            elif high > tp1 and high > tp2:
                close_position(tp2)  
            elif high > tp1:
                close_position(tp1)
                
            # close_position(tp1)
            
            return 1, 'profit'


    elif current_position == -1 :
        if high > sl:
            print('high ', high,' sl', sl)
            print("SL Active SELL")
            
            close_position(sl)
            
            return -1, 'loss'
        
        if low < tp1 or low < tp2 or low < tp3:
            print('low ', low, ' tp ', tp1, tp2, tp3)
            print("TP Active SELL")
            

            if low < tp3 and low < tp2 and low < tp3:
                close_position(tp3)
            elif low < tp1 and low < tp2:
                close_position(tp2)
            elif low < tp1:
                close_position(tp1)

            # close_position(tp1)
            
            return -1, 'profit'

    return None, None

# %%
def refresh(order):
    global history, current_position, previous_position, trade_log
    
    signal = order['Signal']
    price = order['Open']     
    low = order['Low']
    high = order['High']
    sl = order['Sl']
    tp1 = order['Tp1']
    tp2 = order['Tp2']
    tp3 = order['Tp3']


    print('*************** new data received ***************')   
    print(previous_position, 'prev')
    print(current_position, 'curr')
    print('open', price)
    print('low', low)
    print('high', high)
    print('sl', sl)
    print('tp1', tp1)
    print('tp2', tp2)
    print('tp3', tp3)
    print('*************************************************')


      #####################################################################################################
      # Check Sl Tp
      #####################################################################################################

    if current_position != 0 :
        
        # Check Tp Sl and save the data
        direction, status = check_tp_sl(order)
        
        # Check profit or loss and save to history
        if status :
            history['Status'].iloc[-1] = status
            current_position = 0
            previous_position = direction
            return None
        
        
      #####################################################################################################
      # Open or Close Position
      #####################################################################################################

       
    if signal != np.nan:
        print("Step: " , i, "      Signal is : " , signal)


        #open long
        if signal == 1 and current_position == 0 and previous_position != 1:
            print("Open Long Position")
            
            open_position('long', price, 1, 10)
            
            current_position = signal
            history.loc[len(history)] = [signal, sl, tp1, tp2, tp3, '']


        #Close short, open long
        elif signal == 1 and current_position == -1:
            print("Close Short Position")
            print("Open Long Position")
            
            close_position(price)
            open_position('long', price, 1, 10)
            
            history['Status'].iloc[-1] = 'Direction Changed'
            current_position = signal
            history.loc[len(history)] = [signal, sl, tp1, tp2, tp3, '']



        # open short
        elif signal == -1 and current_position == 0 and previous_position != -1:
            print("Open Short Position")
            
            open_position('short', price, 1, 10)
            
            current_position = signal
            history.loc[len(history)] = [signal, sl, tp1, tp2, tp3, '']


        # close long, open short
        elif signal == -1 and current_position == 1:
            print("Close Long Position")
            print("Open Short Position")
            
            close_position(price)
            open_position('short', price, 1, 10)
            
            history['Status'].iloc[-1] = 'Direction Changed'
            current_position = signal
            history.loc[len(history)] = [signal, sl, tp1, tp2, tp3, '']



# Call refresh by every new data
for i in range(len(generated_signals)):
    new_data = generated_signals.iloc[i]
    
    refresh(new_data)
      

history
# Out:
# *************** new data received ***************
# 0 prev
# 0 curr
# open 21278
# low 85125
# high 99803
# sl 20214.1
# tp1 21490.78
# tp2 21597.17
# tp3 21703.56
# *************************************************
# Step:  0       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 21278 1 10
# *************** new data received ***************
# 0 prev
# 1.0 curr
# open 44945
# low 24247
# high 64440
# sl 47192.25
# tp1 44495.55
# tp2 44270.825
# tp3 44046.1
# *************************************************
# high  64440  tp  21490.78 21597.17 21703.56
# TP Active Long
# close ********************** 21703.56
# calculate ***************** 21278 21703.56 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 1525
# low 48916
# high 81761
# sl 1601.25
# tp1 1509.75
# tp2 1502.125
# tp3 1494.5
# *************************************************
# Step:  2       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 1525 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 20509
# low 40083
# high 93595
# sl 21534.45
# tp1 20303.91
# tp2 20201.364999999998
# tp3 20098.82
# *************************************************
# high  93595  sl 1601.25
# SL Active SELL
# close ********************** 1601.25
# calculate ***************** 1525 1601.25 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 59570
# low 19537
# high 24327
# sl 56591.5
# tp1 60165.7
# tp2 60463.549999999996
# tp3 60761.4
# *************************************************
# Step:  4       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 59570 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 62818
# low 47658
# high 32336
# sl 59677.1
# tp1 63446.18
# tp2 63760.27
# tp3 64074.36
# *************************************************
# low  47658  sl 56591.5
# SL Active Long
# close ********************** 56591.5
# calculate ***************** 59570 56591.5 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 4514
# low 42827
# high 75585
# sl 4288.3
# tp1 4559.14
# tp2 4581.709999999999
# tp3 4604.28
# *************************************************
# Step:  6       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 84173
# low 2127
# high 71243
# sl 88381.65000000001
# tp1 83331.27
# tp2 82910.405
# tp3 82489.54
# *************************************************
# Step:  7       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 84173 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 75168
# low 76044
# high 77002
# sl 71409.59999999999
# tp1 75919.68000000001
# tp2 76295.51999999999
# tp3 76671.36
# *************************************************
# low  76044  tp  83331.27 82910.405 82489.54
# TP Active SELL
# close ********************** 82489.54
# calculate ***************** 84173 82489.54 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 78686
# low 83714
# high 88411
# sl 74751.7
# tp1 79472.86
# tp2 79866.29
# tp3 80259.72
# *************************************************
# Step:  9       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 78686 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 82171
# low 85198
# high 80398
# sl 78062.45
# tp1 82992.71
# tp2 83403.56499999999
# tp3 83814.42
# *************************************************
# high  80398  tp  79472.86 79866.29 80259.72
# TP Active Long
# close ********************** 80259.72
# calculate ***************** 78686 80259.72 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 94891
# low 81882
# high 80089
# sl 90146.45
# tp1 95839.91
# tp2 96314.36499999999
# tp3 96788.82
# *************************************************
# Step:  11       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 10165
# low 97874
# high 11002
# sl 10673.25
# tp1 10063.35
# tp2 10012.525
# tp3 9961.7
# *************************************************
# Step:  12       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 10165 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 52025
# low 89415
# high 94128
# sl 54626.25
# tp1 51504.75
# tp2 51244.625
# tp3 50984.5
# *************************************************
# high  94128  sl 10673.25
# SL Active SELL
# close ********************** 10673.25
# calculate ***************** 10165 10673.25 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 87652
# low 42403
# high 23000
# sl 83269.4
# tp1 88528.52
# tp2 88966.77999999998
# tp3 89405.04000000001
# *************************************************
# Step:  14       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 87652 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 98496
# low 11777
# high 2692
# sl 93571.2
# tp1 99480.96
# tp2 99973.43999999999
# tp3 100465.92
# *************************************************
# low  11777  sl 83269.4
# SL Active Long
# close ********************** 83269.4
# calculate ***************** 87652 83269.4 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 67061
# low 56065
# high 27850
# sl 63707.95
# tp1 67731.61
# tp2 68066.915
# tp3 68402.22
# *************************************************
# Step:  16       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 75557
# low 70016
# high 93819
# sl 79334.85
# tp1 74801.43
# tp2 74423.645
# tp3 74045.86
# *************************************************
# Step:  17       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 75557 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 10794
# low 41158
# high 66048
# sl 11333.7
# tp1 10686.06
# tp2 10632.09
# tp3 10578.119999999999
# *************************************************
# low  41158  tp  74801.43 74423.645 74045.86
# TP Active SELL
# close ********************** 74045.86
# calculate ***************** 75557 74045.86 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 31992
# low 50237
# high 58170
# sl 33591.6
# tp1 31672.079999999998
# tp2 31512.12
# tp3 31352.16
# *************************************************
# Step:  19       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 1250
# low 23946
# high 93655
# sl 1312.5
# tp1 1237.5
# tp2 1231.25
# tp3 1225.0
# *************************************************
# Step:  20       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 2430
# low 4354
# high 17658
# sl 2551.5
# tp1 2405.7
# tp2 2393.55
# tp3 2381.4
# *************************************************
# Step:  21       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 17744
# low 70377
# high 96087
# sl 18631.2
# tp1 17566.56
# tp2 17477.84
# tp3 17389.12
# *************************************************
# Step:  22       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 98689
# low 28158
# high 75862
# sl 93754.54999999999
# tp1 99675.89
# tp2 100169.33499999999
# tp3 100662.78
# *************************************************
# Step:  23       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 98689 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 44555
# low 43004
# high 47602
# sl 42327.25
# tp1 45000.55
# tp2 45223.325
# tp3 45446.1
# *************************************************
# low  43004  sl 93754.54999999999
# SL Active Long
# close ********************** 93754.54999999999
# calculate ***************** 98689 93754.54999999999 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 15821
# low 84971
# high 23872
# sl 16612.05
# tp1 15662.789999999999
# tp2 15583.685
# tp3 15504.58
# *************************************************
# Step:  25       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 15821 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 75076
# low 73201
# high 83183
# sl 78829.8
# tp1 74325.24
# tp2 73949.86
# tp3 73574.48
# *************************************************
# high  83183  sl 16612.05
# SL Active SELL
# close ********************** 16612.05
# calculate ***************** 15821 16612.05 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 79610
# low 92641
# high 16476
# sl 75629.5
# tp1 80406.1
# tp2 80804.15
# tp3 81202.2
# *************************************************
# Step:  27       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 79610 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 19031
# low 18925
# high 80000
# sl 18079.45
# tp1 19221.31
# tp2 19316.464999999997
# tp3 19411.62
# *************************************************
# low  18925  sl 75629.5
# SL Active Long
# close ********************** 75629.5
# calculate ***************** 79610 75629.5 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 20292
# low 32935
# high 42127
# sl 21306.600000000002
# tp1 20089.079999999998
# tp2 19987.62
# tp3 19886.16
# *************************************************
# Step:  29       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 20292 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 94365
# low 62164
# high 49228
# sl 99083.25
# tp1 93421.35
# tp2 92949.525
# tp3 92477.7
# *************************************************
# high  49228  sl 21306.600000000002
# SL Active SELL
# close ********************** 21306.600000000002
# calculate ***************** 20292 21306.600000000002 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 54983
# low 9173
# high 97002
# sl 52233.85
# tp1 55532.83
# tp2 55807.744999999995
# tp3 56082.66
# *************************************************
# Step:  31       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 54983 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 68195
# low 18327
# high 11330
# sl 64785.25
# tp1 68876.95
# tp2 69217.92499999999
# tp3 69558.9
# *************************************************
# low  18327  sl 52233.85
# SL Active Long
# close ********************** 52233.85
# calculate ***************** 54983 52233.85 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 70917
# low 88160
# high 92077
# sl 67371.15
# tp1 71626.17
# tp2 71980.75499999999
# tp3 72335.34
# *************************************************
# Step:  33       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 36634
# low 47792
# high 72440
# sl 38465.700000000004
# tp1 36267.659999999996
# tp2 36084.49
# tp3 35901.32
# *************************************************
# Step:  34       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 36634 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 39376
# low 72642
# high 58227
# sl 41344.8
# tp1 38982.24
# tp2 38785.36
# tp3 38588.479999999996
# *************************************************
# high  58227  sl 38465.700000000004
# SL Active SELL
# close ********************** 38465.700000000004
# calculate ***************** 36634 38465.700000000004 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 35560
# low 38624
# high 60482
# sl 37338.0
# tp1 35204.4
# tp2 35026.6
# tp3 34848.8
# *************************************************
# Step:  36       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 29205
# low 71484
# high 2077
# sl 30665.25
# tp1 28912.95
# tp2 28766.925
# tp3 28620.899999999998
# *************************************************
# Step:  37       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 60696
# low 34435
# high 94373
# sl 57661.2
# tp1 61302.96
# tp2 61606.439999999995
# tp3 61909.92
# *************************************************
# Step:  38       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 60696 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 16926
# low 91842
# high 96132
# sl 16079.699999999999
# tp1 17095.26
# tp2 17179.89
# tp3 17264.52
# *************************************************
# high  96132  tp  61302.96 61606.439999999995 61909.92
# TP Active Long
# close ********************** 61909.92
# calculate ***************** 60696 61909.92 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 13286
# low 41495
# high 68732
# sl 13950.300000000001
# tp1 13153.14
# tp2 13086.71
# tp3 13020.28
# *************************************************
# Step:  40       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 13286 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 16909
# low 79852
# high 11475
# sl 17754.45
# tp1 16739.91
# tp2 16655.364999999998
# tp3 16570.82
# *************************************************
# Step:  41       Signal is :  -1.0
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 57753
# low 88803
# high 5234
# sl 54865.35
# tp1 58330.53
# tp2 58619.29499999999
# tp3 58908.06
# *************************************************
# Step:  42       Signal is :  1.0
# Close Short Position
# Open Long Position
# close ********************** 57753
# calculate ***************** 13286 57753.0 short 1 10
# Balance Management
# open ********************** long 57753 1 10
# *************** new data received ***************
# 1 prev
# 1.0 curr
# open 78174
# low 32849
# high 8771
# sl 74265.3
# tp1 78955.74
# tp2 79346.60999999999
# tp3 79737.48
# *************************************************
# low  32849  sl 54865.35
# SL Active Long
# close ********************** 54865.35
# calculate ***************** 57753 54865.35 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 1967
# low 34177
# high 54558
# sl 1868.6499999999999
# tp1 1986.67
# tp2 1996.5049999999999
# tp3 2006.3400000000001
# *************************************************
# Step:  44       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 20009
# low 78273
# high 12163
# sl 21009.45
# tp1 19808.91
# tp2 19708.864999999998
# tp3 19608.82
# *************************************************
# Step:  45       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 20009 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 26175
# low 54428
# high 21547
# sl 27483.75
# tp1 25913.25
# tp2 25782.375
# tp3 25651.5
# *************************************************
# high  21547  sl 21009.45
# SL Active SELL
# close ********************** 21009.45
# calculate ***************** 20009 21009.45 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 73620
# low 82678
# high 98317
# sl 69939.0
# tp1 74356.2
# tp2 74724.29999999999
# tp3 75092.4
# *************************************************
# Step:  47       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 73620 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 15529
# low 5934
# high 90413
# sl 14752.55
# tp1 15684.29
# tp2 15761.934999999998
# tp3 15839.58
# *************************************************
# low  5934  sl 69939.0
# SL Active Long
# close ********************** 69939.0
# calculate ***************** 73620 69939.0 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 78154
# low 40523
# high 55210
# sl 74246.3
# tp1 78935.54
# tp2 79326.31
# tp3 79717.08
# *************************************************
# Step:  49       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 59071
# low 42667
# high 36640
# sl 56117.45
# tp1 59661.71
# tp2 59957.064999999995
# tp3 60252.42
# *************************************************
# Step:  50       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 80342
# low 86328
# high 90073
# sl 76324.9
# tp1 81145.42
# tp2 81547.12999999999
# tp3 81948.84
# *************************************************
# Step:  51       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 31128
# low 43348
# high 82395
# sl 29571.6
# tp1 31439.28
# tp2 31594.92
# tp3 31750.56
# *************************************************
# Step:  52       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 65984
# low 28782
# high 22653
# sl 69283.2
# tp1 65324.159999999996
# tp2 64994.24
# tp3 64664.32
# *************************************************
# Step:  53       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 65984 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 86283
# low 44042
# high 81381
# sl 81968.84999999999
# tp1 87145.83
# tp2 87577.245
# tp3 88008.66
# *************************************************
# high  81381  sl 69283.2
# SL Active SELL
# close ********************** 69283.2
# calculate ***************** 65984 69283.2 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 49391
# low 23423
# high 88047
# sl 46921.45
# tp1 49884.91
# tp2 50131.865
# tp3 50378.82
# *************************************************
# Step:  55       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 49391 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 63951
# low 21879
# high 56837
# sl 67148.55
# tp1 63311.49
# tp2 62991.735
# tp3 62671.979999999996
# *************************************************
# low  21879  sl 46921.45
# SL Active Long
# close ********************** 46921.45
# calculate ***************** 49391 46921.45 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 17772
# low 50341
# high 9189
# sl 18660.600000000002
# tp1 17594.28
# tp2 17505.42
# tp3 17416.56
# *************************************************
# Step:  57       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 17772 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 48906
# low 49979
# high 56239
# sl 51351.3
# tp1 48416.94
# tp2 48172.409999999996
# tp3 47927.88
# *************************************************
# high  56239  sl 18660.600000000002
# SL Active SELL
# close ********************** 18660.600000000002
# calculate ***************** 17772 18660.600000000002 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 20413
# low 4559
# high 69417
# sl 21433.65
# tp1 20208.87
# tp2 20106.805
# tp3 20004.739999999998
# *************************************************
# Step:  59       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 9140
# low 58321
# high 40754
# sl 9597.0
# tp1 9048.6
# tp2 9002.9
# tp3 8957.2
# *************************************************
# Step:  60       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 17994
# low 71594
# high 89763
# sl 18893.7
# tp1 17814.06
# tp2 17724.09
# tp3 17634.12
# *************************************************
# Step:  61       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 86705
# low 31543
# high 23556
# sl 82369.75
# tp1 87572.05
# tp2 88005.575
# tp3 88439.1
# *************************************************
# Step:  62       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 86705 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 18814
# low 22924
# high 92799
# sl 17873.3
# tp1 19002.14
# tp2 19096.21
# tp3 19190.28
# *************************************************
# low  22924  sl 82369.75
# SL Active Long
# close ********************** 82369.75
# calculate ***************** 86705 82369.75 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 84388
# low 11897
# high 90015
# sl 80168.59999999999
# tp1 85231.88
# tp2 85653.81999999999
# tp3 86075.76
# *************************************************
# Step:  64       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 91703
# low 14387
# high 78423
# sl 87117.84999999999
# tp1 92620.03
# tp2 93078.545
# tp3 93537.06
# *************************************************
# Step:  65       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 20971
# low 20887
# high 57412
# sl 22019.55
# tp1 20761.29
# tp2 20656.435
# tp3 20551.579999999998
# *************************************************
# Step:  66       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 20971 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 9763
# low 36302
# high 82173
# sl 10251.15
# tp1 9665.37
# tp2 9616.555
# tp3 9567.74
# *************************************************
# high  82173  sl 22019.55
# SL Active SELL
# close ********************** 22019.55
# calculate ***************** 20971 22019.55 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 22301
# low 32570
# high 48381
# sl 23416.05
# tp1 22077.99
# tp2 21966.485
# tp3 21854.98
# *************************************************
# Step:  68       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 65110
# low 14801
# high 16126
# sl 61854.5
# tp1 65761.1
# tp2 66086.65
# tp3 66412.2
# *************************************************
# Step:  69       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 65110 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 97626
# low 59947
# high 25904
# sl 92744.7
# tp1 98602.26
# tp2 99090.38999999998
# tp3 99578.52
# *************************************************
# low  59947  sl 61854.5
# SL Active Long
# close ********************** 61854.5
# calculate ***************** 65110 61854.5 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 3122
# low 15717
# high 21802
# sl 2965.8999999999996
# tp1 3153.2200000000003
# tp2 3168.8299999999995
# tp3 3184.44
# *************************************************
# Step:  71       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 79198
# low 29175
# high 63519
# sl 83157.90000000001
# tp1 78406.02
# tp2 78010.03
# tp3 77614.04
# *************************************************
# Step:  72       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 79198 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 98835
# low 36585
# high 17466
# sl 93893.25
# tp1 99823.35
# tp2 100317.525
# tp3 100811.7
# *************************************************
# low  36585  tp  78406.02 78010.03 77614.04
# TP Active SELL
# close ********************** 77614.04
# calculate ***************** 79198 77614.04 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 68078
# low 27347
# high 15580
# sl 64674.1
# tp1 68758.78
# tp2 69099.17
# tp3 69439.56
# *************************************************
# Step:  74       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 68078 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 70641
# low 36870
# high 60145
# sl 67108.95
# tp1 71347.41
# tp2 71700.61499999999
# tp3 72053.82
# *************************************************
# low  36870  sl 64674.1
# SL Active Long
# close ********************** 64674.1
# calculate ***************** 68078 64674.1 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 68822
# low 60145
# high 54624
# sl 72263.1
# tp1 68133.78
# tp2 67789.67
# tp3 67445.56
# *************************************************
# Step:  76       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 68822 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 74791
# low 62718
# high 79
# sl 78530.55
# tp1 74043.09
# tp2 73669.135
# tp3 73295.18
# *************************************************
# low  62718  tp  68133.78 67789.67 67445.56
# TP Active SELL
# close ********************** 67445.56
# calculate ***************** 68822 67445.56 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 25691
# low 82858
# high 22276
# sl 26975.550000000003
# tp1 25434.09
# tp2 25305.635
# tp3 25177.18
# *************************************************
# Step:  78       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 37806
# low 90195
# high 35626
# sl 39696.3
# tp1 37427.94
# tp2 37238.909999999996
# tp3 37049.88
# *************************************************
# Step:  79       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 93364
# low 52992
# high 59911
# sl 88695.8
# tp1 94297.64
# tp2 94764.45999999999
# tp3 95231.28
# *************************************************
# Step:  80       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 93364 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 99808
# low 34404
# high 9160
# sl 94817.59999999999
# tp1 100806.08
# tp2 101305.12
# tp3 101804.16
# *************************************************
# low  34404  sl 88695.8
# SL Active Long
# close ********************** 88695.8
# calculate ***************** 93364 88695.8 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 18020
# low 71043
# high 65585
# sl 17119.0
# tp1 18200.2
# tp2 18290.3
# tp3 18380.4
# *************************************************
# Step:  82       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 89381
# low 8803
# high 30141
# sl 93850.05
# tp1 88487.19
# tp2 88040.285
# tp3 87593.38
# *************************************************
# Step:  83       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 89381 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 25880
# low 18645
# high 88219
# sl 27174.0
# tp1 25621.2
# tp2 25491.8
# tp3 25362.399999999998
# *************************************************
# low  18645  tp  88487.19 88040.285 87593.38
# TP Active SELL
# close ********************** 87593.38
# calculate ***************** 89381 87593.38 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 10904
# low 65231
# high 94635
# sl 11449.2
# tp1 10794.96
# tp2 10740.44
# tp3 10685.92
# *************************************************
# Step:  85       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 12134
# low 46536
# high 88435
# sl 12740.7
# tp1 12012.66
# tp2 11951.99
# tp3 11891.32
# *************************************************
# Step:  86       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 60946
# low 69305
# high 31182
# sl 63993.3
# tp1 60336.54
# tp2 60031.81
# tp3 59727.08
# *************************************************
# Step:  87       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 22987
# low 91387
# high 36048
# sl 21837.649999999998
# tp1 23216.87
# tp2 23331.804999999997
# tp3 23446.74
# *************************************************
# Step:  88       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 22987 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 40480
# low 21683
# high 38532
# sl 38456.0
# tp1 40884.8
# tp2 41087.2
# tp3 41289.6
# *************************************************
# low  21683  sl 21837.649999999998
# SL Active Long
# close ********************** 21837.649999999998
# calculate ***************** 22987 21837.649999999998 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 86293
# low 81789
# high 21362
# sl 81978.34999999999
# tp1 87155.93000000001
# tp2 87587.39499999999
# tp3 88018.86
# *************************************************
# Step:  90       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 29792
# low 61346
# high 17353
# sl 28302.399999999998
# tp1 30089.920000000002
# tp2 30238.879999999997
# tp3 30387.84
# *************************************************
# Step:  91       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 43519
# low 29425
# high 88126
# sl 45694.950000000004
# tp1 43083.81
# tp2 42866.215
# tp3 42648.62
# *************************************************
# Step:  92       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 43519 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 23295
# low 4052
# high 86920
# sl 24459.75
# tp1 23062.05
# tp2 22945.575
# tp3 22829.1
# *************************************************
# high  86920  sl 45694.950000000004
# SL Active SELL
# close ********************** 45694.950000000004
# calculate ***************** 43519 45694.950000000004 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 79242
# low 54993
# high 89921
# sl 83204.1
# tp1 78449.58
# tp2 78053.37
# tp3 77657.16
# *************************************************
# Step:  94       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 93129
# low 5300
# high 74826
# sl 88472.55
# tp1 94060.29
# tp2 94525.935
# tp3 94991.58
# *************************************************
# Step:  95       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 93129 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 34572
# low 75249
# high 6674
# sl 32843.4
# tp1 34917.72
# tp2 35090.579999999994
# tp3 35263.44
# *************************************************
# low  75249  sl 88472.55
# SL Active Long
# close ********************** 88472.55
# calculate ***************** 93129 88472.55 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 4476
# low 59791
# high 27711
# sl 4699.8
# tp1 4431.24
# tp2 4408.86
# tp3 4386.48
# *************************************************
# Step:  97       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 4476 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 23420
# low 94312
# high 35739
# sl 24591.0
# tp1 23185.8
# tp2 23068.7
# tp3 22951.6
# *************************************************
# high  35739  sl 4699.8
# SL Active SELL
# close ********************** 4699.8
# calculate ***************** 4476 4699.8 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 90555
# low 25103
# high 15335
# sl 86027.25
# tp1 91460.55
# tp2 91913.325
# tp3 92366.1
# *************************************************
# Step:  99       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 90555 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 82353
# low 12119
# high 95582
# sl 78235.34999999999
# tp1 83176.53
# tp2 83588.295
# tp3 84000.06
# *************************************************
# low  12119  sl 86027.25
# SL Active Long
# close ********************** 86027.25
# calculate ***************** 90555 86027.25 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 35689
# low 42753
# high 76966
# sl 33904.549999999996
# tp1 36045.89
# tp2 36224.335
# tp3 36402.78
# *************************************************
# Step:  101       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 30800
# low 48206
# high 77036
# sl 32340.0
# tp1 30492.0
# tp2 30338.0
# tp3 30184.0
# *************************************************
# Step:  102       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 30800 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 49014
# low 38348
# high 3673
# sl 51464.700000000004
# tp1 48523.86
# tp2 48278.79
# tp3 48033.72
# *************************************************
# Step:  103       Signal is :  -1.0
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 81887
# low 64411
# high 4166
# sl 77792.65
# tp1 82705.87
# tp2 83115.305
# tp3 83524.74
# *************************************************
# Step:  104       Signal is :  1.0
# Close Short Position
# Open Long Position
# close ********************** 81887
# calculate ***************** 30800 81887.0 short 1 10
# Balance Management
# open ********************** long 81887 1 10
# *************** new data received ***************
# 1 prev
# 1.0 curr
# open 9605
# low 27856
# high 83587
# sl 9124.75
# tp1 9701.05
# tp2 9749.074999999999
# tp3 9797.1
# *************************************************
# low  27856  sl 77792.65
# SL Active Long
# close ********************** 77792.65
# calculate ***************** 81887 77792.65 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 52050
# low 87469
# high 33008
# sl 54652.5
# tp1 51529.5
# tp2 51269.25
# tp3 51009.0
# *************************************************
# Step:  106       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 52050 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 6858
# low 21491
# high 59926
# sl 7200.900000000001
# tp1 6789.42
# tp2 6755.13
# tp3 6720.84
# *************************************************
# high  59926  sl 54652.5
# SL Active SELL
# close ********************** 54652.5
# calculate ***************** 52050 54652.5 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 24023
# low 49856
# high 60074
# sl 25224.15
# tp1 23782.77
# tp2 23662.655
# tp3 23542.54
# *************************************************
# Step:  108       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 13223
# low 79490
# high 65849
# sl 13884.150000000001
# tp1 13090.77
# tp2 13024.655
# tp3 12958.539999999999
# *************************************************
# Step:  109       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 6395
# low 50018
# high 64648
# sl 6714.75
# tp1 6331.05
# tp2 6299.075
# tp3 6267.099999999999
# *************************************************
# Step:  110       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 5735
# low 93270
# high 13631
# sl 6021.75
# tp1 5677.65
# tp2 5648.975
# tp3 5620.3
# *************************************************
# Step:  111       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 58493
# low 27915
# high 48325
# sl 55568.35
# tp1 59077.93
# tp2 59370.395
# tp3 59662.86
# *************************************************
# Step:  112       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 58493 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 33583
# low 56397
# high 30464
# sl 31903.85
# tp1 33918.83
# tp2 34086.744999999995
# tp3 34254.66
# *************************************************
# Step:  113       Signal is :  1.0
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 84387
# low 17923
# high 83575
# sl 80167.65
# tp1 85230.87
# tp2 85652.805
# tp3 86074.74
# *************************************************
# low  17923  sl 55568.35
# SL Active Long
# close ********************** 55568.35
# calculate ***************** 58493 55568.35 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 56492
# low 15994
# high 22764
# sl 53667.399999999994
# tp1 57056.92
# tp2 57339.38
# tp3 57621.840000000004
# *************************************************
# Step:  115       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 19041
# low 77661
# high 11684
# sl 19993.05
# tp1 18850.59
# tp2 18755.385
# tp3 18660.18
# *************************************************
# Step:  116       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 19041 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 96505
# low 71118
# high 36207
# sl 101330.25
# tp1 95539.95
# tp2 95057.425
# tp3 94574.9
# *************************************************
# high  36207  sl 19993.05
# SL Active SELL
# close ********************** 19993.05
# calculate ***************** 19041 19993.05 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 82464
# low 27254
# high 880
# sl 78340.8
# tp1 83288.64
# tp2 83700.95999999999
# tp3 84113.28
# *************************************************
# Step:  118       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 82464 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 98373
# low 40218
# high 53241
# sl 93454.34999999999
# tp1 99356.73
# tp2 99848.59499999999
# tp3 100340.46
# *************************************************
# low  40218  sl 78340.8
# SL Active Long
# close ********************** 78340.8
# calculate ***************** 82464 78340.8 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 12445
# low 91226
# high 41188
# sl 13067.25
# tp1 12320.55
# tp2 12258.325
# tp3 12196.1
# *************************************************
# Step:  120       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 12445 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 2930
# low 71892
# high 26065
# sl 3076.5
# tp1 2900.7
# tp2 2886.05
# tp3 2871.4
# *************************************************
# high  26065  sl 13067.25
# SL Active SELL
# close ********************** 13067.25
# calculate ***************** 12445 13067.25 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 62004
# low 73742
# high 74741
# sl 65104.200000000004
# tp1 61383.96
# tp2 61073.94
# tp3 60763.92
# *************************************************
# Step:  122       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 82226
# low 37229
# high 82540
# sl 78114.7
# tp1 83048.26
# tp2 83459.38999999998
# tp3 83870.52
# *************************************************
# Step:  123       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 82226 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 8591
# low 1014
# high 85544
# sl 8161.45
# tp1 8676.91
# tp2 8719.865
# tp3 8762.82
# *************************************************
# low  1014  sl 78114.7
# SL Active Long
# close ********************** 78114.7
# calculate ***************** 82226 78114.7 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 45871
# low 10090
# high 55245
# sl 48164.55
# tp1 45412.29
# tp2 45182.935
# tp3 44953.58
# *************************************************
# Step:  125       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 45871 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 99317
# low 77060
# high 62118
# sl 94351.15
# tp1 100310.17
# tp2 100806.75499999999
# tp3 101303.34
# *************************************************
# high  62118  sl 48164.55
# SL Active SELL
# close ********************** 48164.55
# calculate ***************** 45871 48164.55 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 72058
# low 45221
# high 17413
# sl 68455.09999999999
# tp1 72778.58
# tp2 73138.87
# tp3 73499.16
# *************************************************
# Step:  127       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 72058 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 22192
# low 52094
# high 82179
# sl 23301.600000000002
# tp1 21970.079999999998
# tp2 21859.12
# tp3 21748.16
# *************************************************
# low  52094  sl 68455.09999999999
# SL Active Long
# close ********************** 68455.09999999999
# calculate ***************** 72058 68455.09999999999 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 16677
# low 58269
# high 4630
# sl 17510.850000000002
# tp1 16510.23
# tp2 16426.845
# tp3 16343.46
# *************************************************
# Step:  129       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 16677 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 74046
# low 81597
# high 80777
# sl 77748.3
# tp1 73305.54
# tp2 72935.31
# tp3 72565.08
# *************************************************
# high  80777  sl 17510.850000000002
# SL Active SELL
# close ********************** 17510.850000000002
# calculate ***************** 16677 17510.850000000002 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 88162
# low 39033
# high 1087
# sl 83753.9
# tp1 89043.62
# tp2 89484.43
# tp3 89925.24
# *************************************************
# Step:  131       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 88162 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 40757
# low 34459
# high 84475
# sl 38719.15
# tp1 41164.57
# tp2 41368.354999999996
# tp3 41572.14
# *************************************************
# low  34459  sl 83753.9
# SL Active Long
# close ********************** 83753.9
# calculate ***************** 88162 83753.9 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 51160
# low 98243
# high 26190
# sl 53718.0
# tp1 50648.4
# tp2 50392.6
# tp3 50136.799999999996
# *************************************************
# Step:  133       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 51160 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 3080
# low 79672
# high 5534
# sl 3234.0
# tp1 3049.2
# tp2 3033.8
# tp3 3018.4
# *************************************************
# Step:  134       Signal is :  -1.0
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 37986
# low 84659
# high 25871
# sl 39885.3
# tp1 37606.14
# tp2 37416.21
# tp3 37226.28
# *************************************************
# Step:  135       Signal is :  -1.0
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 18172
# low 20840
# high 61838
# sl 19080.600000000002
# tp1 17990.28
# tp2 17899.42
# tp3 17808.56
# *************************************************
# high  61838  sl 53718.0
# SL Active SELL
# close ********************** 53718.0
# calculate ***************** 51160 53718.0 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 64373
# low 60938
# high 84708
# sl 61154.35
# tp1 65016.73
# tp2 65338.594999999994
# tp3 65660.46
# *************************************************
# Step:  137       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 64373 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 4992
# low 81483
# high 77425
# sl 4742.4
# tp1 5041.92
# tp2 5066.879999999999
# tp3 5091.84
# *************************************************
# high  77425  tp  65016.73 65338.594999999994 65660.46
# TP Active Long
# close ********************** 65660.46
# calculate ***************** 64373 65660.46 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 87635
# low 41854
# high 8621
# sl 83253.25
# tp1 88511.35
# tp2 88949.525
# tp3 89387.7
# *************************************************
# Step:  139       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 87881
# low 63866
# high 36184
# sl 83486.95
# tp1 88759.81
# tp2 89199.215
# tp3 89638.62
# *************************************************
# Step:  140       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 67760
# low 9085
# high 91867
# sl 64372.0
# tp1 68437.6
# tp2 68776.4
# tp3 69115.2
# *************************************************
# Step:  141       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 76280
# low 74153
# high 30900
# sl 72466.0
# tp1 77042.8
# tp2 77424.2
# tp3 77805.6
# *************************************************
# Step:  142       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 35791
# low 58338
# high 8513
# sl 37580.55
# tp1 35433.09
# tp2 35254.135
# tp3 35075.18
# *************************************************
# Step:  143       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 35791 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 81673
# low 78502
# high 88010
# sl 85756.65000000001
# tp1 80856.27
# tp2 80447.905
# tp3 80039.54
# *************************************************
# high  88010  sl 37580.55
# SL Active SELL
# close ********************** 37580.55
# calculate ***************** 35791 37580.55 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 16587
# low 45322
# high 24330
# sl 17416.350000000002
# tp1 16421.13
# tp2 16338.195
# tp3 16255.26
# *************************************************
# Step:  145       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 44783
# low 30487
# high 73369
# sl 47022.15
# tp1 44335.17
# tp2 44111.255
# tp3 43887.34
# *************************************************
# Step:  146       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 82043
# low 75501
# high 70329
# sl 77940.84999999999
# tp1 82863.43000000001
# tp2 83273.64499999999
# tp3 83683.86
# *************************************************
# Step:  147       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 82043 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 44667
# low 299
# high 26746
# sl 42433.65
# tp1 45113.67
# tp2 45337.005
# tp3 45560.340000000004
# *************************************************
# low  299  sl 77940.84999999999
# SL Active Long
# close ********************** 77940.84999999999
# calculate ***************** 82043 77940.84999999999 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 71155
# low 55991
# high 63898
# sl 67597.25
# tp1 71866.55
# tp2 72222.325
# tp3 72578.1
# *************************************************
# Step:  149       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 38911
# low 22032
# high 99664
# sl 40856.55
# tp1 38521.89
# tp2 38327.335
# tp3 38132.78
# *************************************************
# Step:  150       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 38911 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 2685
# low 574
# high 83080
# sl 2819.25
# tp1 2658.15
# tp2 2644.725
# tp3 2631.2999999999997
# *************************************************
# high  83080  sl 40856.55
# SL Active SELL
# close ********************** 40856.55
# calculate ***************** 38911 40856.55 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 68159
# low 95649
# high 32
# sl 71566.95
# tp1 67477.41
# tp2 67136.615
# tp3 66795.81999999999
# *************************************************
# Step:  152       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 67930
# low 23898
# high 81313
# sl 64533.5
# tp1 68609.3
# tp2 68948.95
# tp3 69288.6
# *************************************************
# Step:  153       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 67930 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 93260
# low 51428
# high 36430
# sl 88597.0
# tp1 94192.6
# tp2 94658.9
# tp3 95125.2
# *************************************************
# low  51428  sl 64533.5
# SL Active Long
# close ********************** 64533.5
# calculate ***************** 67930 64533.5 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 93933
# low 81309
# high 41999
# sl 89236.34999999999
# tp1 94872.33
# tp2 95341.995
# tp3 95811.66
# *************************************************
# Step:  155       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 79549
# low 22814
# high 21694
# sl 75571.55
# tp1 80344.49
# tp2 80742.23499999999
# tp3 81139.98
# *************************************************
# Step:  156       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 24532
# low 73127
# high 27712
# sl 25758.600000000002
# tp1 24286.68
# tp2 24164.02
# tp3 24041.36
# *************************************************
# Step:  157       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 24532 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 18889
# low 86092
# high 34756
# sl 19833.45
# tp1 18700.11
# tp2 18605.665
# tp3 18511.22
# *************************************************
# high  34756  sl 25758.600000000002
# SL Active SELL
# close ********************** 25758.600000000002
# calculate ***************** 24532 25758.600000000002 short 1 10
# ...
# 1 prev
# -1.0 curr
# open 46943
# low 96379
# high 96782
# sl 49290.15
# tp1 46473.57
# tp2 46238.854999999996
# tp3 46004.14
# *************************************************
# high  96782  sl 11417.7
# SL Active SELL
# close ********************** 11417.7
# calculate ***************** 10874 11417.7 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 58247
# low 36939
# high 92738
# sl 55334.649999999994
# tp1 58829.47
# tp2 59120.704999999994
# tp3 59411.94
# *************************************************
# Step:  663       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 58247 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 58502
# low 99959
# high 59643
# sl 55576.899999999994
# tp1 59087.020000000004
# tp2 59379.52999999999
# tp3 59672.04
# *************************************************
# high  59643  tp  58829.47 59120.704999999994 59411.94
# TP Active Long
# close ********************** 59411.94
# calculate ***************** 58247 59411.94 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 62104
# low 69632
# high 16305
# sl 58998.799999999996
# tp1 62725.04
# tp2 63035.55999999999
# tp3 63346.08
# *************************************************
# Step:  665       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 12440
# low 15202
# high 64469
# sl 13062.0
# tp1 12315.6
# tp2 12253.4
# tp3 12191.199999999999
# *************************************************
# Step:  666       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 12440 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 76972
# low 23813
# high 81132
# sl 80820.6
# tp1 76202.28
# tp2 75817.42
# tp3 75432.56
# *************************************************
# high  81132  sl 13062.0
# SL Active SELL
# close ********************** 13062.0
# calculate ***************** 12440 13062.0 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 28663
# low 66596
# high 72575
# sl 27229.85
# tp1 28949.63
# tp2 29092.944999999996
# tp3 29236.260000000002
# *************************************************
# Step:  668       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 28663 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 80716
# low 41248
# high 47627
# sl 76680.2
# tp1 81523.16
# tp2 81926.73999999999
# tp3 82330.32
# *************************************************
# high  47627  tp  28949.63 29092.944999999996 29236.260000000002
# TP Active Long
# close ********************** 29236.260000000002
# calculate ***************** 28663 29236.260000000002 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 5498
# low 83696
# high 81617
# sl 5223.099999999999
# tp1 5552.9800000000005
# tp2 5580.469999999999
# tp3 5607.96
# *************************************************
# Step:  670       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 72542
# low 78178
# high 48799
# sl 76169.1
# tp1 71816.58
# tp2 71453.87
# tp3 71091.16
# *************************************************
# Step:  671       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 72542 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 32881
# low 87171
# high 54317
# sl 31236.949999999997
# tp1 33209.81
# tp2 33374.215
# tp3 33538.62
# *************************************************
# Step:  672       Signal is :  1.0
# Close Short Position
# Open Long Position
# close ********************** 32881
# calculate ***************** 72542 32881.0 short 1 10
# Balance Management
# open ********************** long 32881 1 10
# *************** new data received ***************
# 1 prev
# 1.0 curr
# open 49646
# low 5933
# high 54526
# sl 52128.3
# tp1 49149.54
# tp2 48901.31
# tp3 48653.08
# *************************************************
# low  5933  sl 31236.949999999997
# SL Active Long
# close ********************** 31236.949999999997
# calculate ***************** 32881 31236.949999999997 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 41028
# low 17535
# high 66929
# sl 38976.6
# tp1 41438.28
# tp2 41643.42
# tp3 41848.56
# *************************************************
# Step:  674       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 67737
# low 10918
# high 60100
# sl 64350.149999999994
# tp1 68414.37
# tp2 68753.055
# tp3 69091.74
# *************************************************
# Step:  675       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 61221
# low 90049
# high 75258
# sl 58159.95
# tp1 61833.21
# tp2 62139.314999999995
# tp3 62445.42
# *************************************************
# Step:  676       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 93921
# low 40940
# high 38876
# sl 89224.95
# tp1 94860.21
# tp2 95329.81499999999
# tp3 95799.42
# *************************************************
# Step:  677       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 17548
# low 28971
# high 22538
# sl 18425.4
# tp1 17372.52
# tp2 17284.78
# tp3 17197.04
# *************************************************
# Step:  678       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 17548 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 13879
# low 60975
# high 87572
# sl 14572.95
# tp1 13740.21
# tp2 13670.815
# tp3 13601.42
# *************************************************
# high  87572  sl 18425.4
# SL Active SELL
# close ********************** 18425.4
# calculate ***************** 17548 18425.4 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 317
# low 80820
# high 47158
# sl 332.85
# tp1 313.83
# tp2 312.245
# tp3 310.65999999999997
# *************************************************
# Step:  680       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 76032
# low 74574
# high 46117
# sl 79833.6
# tp1 75271.68
# tp2 74891.52
# tp3 74511.36
# *************************************************
# Step:  681       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 75904
# low 52942
# high 43666
# sl 72108.8
# tp1 76663.04
# tp2 77042.56
# tp3 77422.08
# *************************************************
# Step:  682       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 75904 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 88485
# low 63076
# high 86476
# sl 84060.75
# tp1 89369.85
# tp2 89812.275
# tp3 90254.7
# *************************************************
# low  63076  sl 72108.8
# SL Active Long
# close ********************** 72108.8
# calculate ***************** 75904 72108.8 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 95170
# low 85771
# high 22132
# sl 90411.5
# tp1 96121.7
# tp2 96597.54999999999
# tp3 97073.40000000001
# *************************************************
# Step:  684       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 23494
# low 94549
# high 99030
# sl 24668.7
# tp1 23259.06
# tp2 23141.59
# tp3 23024.12
# *************************************************
# Step:  685       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 23494 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 60474
# low 87083
# high 40559
# sl 63497.700000000004
# tp1 59869.26
# tp2 59566.89
# tp3 59264.52
# *************************************************
# high  40559  sl 24668.7
# SL Active SELL
# close ********************** 24668.7
# calculate ***************** 23494 24668.7 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 70643
# low 48796
# high 91430
# sl 74175.15000000001
# tp1 69936.56999999999
# tp2 69583.355
# tp3 69230.14
# *************************************************
# Step:  687       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 46394
# low 58313
# high 88223
# sl 48713.700000000004
# tp1 45930.06
# tp2 45698.09
# tp3 45466.12
# *************************************************
# Step:  688       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 9369
# low 62956
# high 47516
# sl 9837.45
# tp1 9275.31
# tp2 9228.465
# tp3 9181.619999999999
# *************************************************
# Step:  689       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 92799
# low 28812
# high 68575
# sl 97438.95
# tp1 91871.01
# tp2 91407.015
# tp3 90943.02
# *************************************************
# Step:  690       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 59132
# low 96269
# high 53951
# sl 56175.399999999994
# tp1 59723.32
# tp2 60018.979999999996
# tp3 60314.64
# *************************************************
# Step:  691       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 59132 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 44841
# low 98338
# high 29535
# sl 42598.95
# tp1 45289.41
# tp2 45513.615
# tp3 45737.82
# *************************************************
# Step:  692       Signal is :  1.0
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 75035
# low 91178
# high 60363
# sl 71283.25
# tp1 75785.35
# tp2 76160.525
# tp3 76535.7
# *************************************************
# high  60363  tp  59723.32 60018.979999999996 60314.64
# TP Active Long
# close ********************** 60314.64
# calculate ***************** 59132 60314.64 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 681
# low 36402
# high 73619
# sl 715.0500000000001
# tp1 674.1899999999999
# tp2 670.785
# tp3 667.38
# *************************************************
# Step:  694       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 681 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 87828
# low 19267
# high 3600
# sl 92219.40000000001
# tp1 86949.72
# tp2 86510.58
# tp3 86071.44
# *************************************************
# high  3600  sl 715.0500000000001
# SL Active SELL
# close ********************** 715.0500000000001
# calculate ***************** 681 715.0500000000001 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 82404
# low 90951
# high 85229
# sl 78283.8
# tp1 83228.04
# tp2 83640.06
# tp3 84052.08
# *************************************************
# Step:  696       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 82404 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 95462
# low 92087
# high 56973
# sl 90688.9
# tp1 96416.62
# tp2 96893.93
# tp3 97371.24
# *************************************************
# Step:  697       Signal is :  1.0
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 16331
# low 97783
# high 82524
# sl 17147.55
# tp1 16167.69
# tp2 16086.035
# tp3 16004.38
# *************************************************
# Step:  698       Signal is :  -1.0
# Close Long Position
# Open Short Position
# close ********************** 16331
# calculate ***************** 82404 16331.0 long 1 10
# Balance Management
# open ********************** short 16331 1 10
# *************** new data received ***************
# -1 prev
# -1.0 curr
# open 3853
# low 70638
# high 93816
# sl 4045.65
# tp1 3814.47
# tp2 3795.205
# tp3 3775.94
# *************************************************
# high  93816  sl 17147.55
# SL Active SELL
# close ********************** 17147.55
# calculate ***************** 16331 17147.55 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 44211
# low 72095
# high 43047
# sl 46421.55
# tp1 43768.89
# tp2 43547.835
# tp3 43326.78
# *************************************************
# Step:  700       Signal is :  -1.0
# *************** new data received ***************
# -1 prev
# 0 curr
# open 78314
# low 31112
# high 34076
# sl 74398.3
# tp1 79097.14
# tp2 79488.70999999999
# tp3 79880.28
# *************************************************
# Step:  701       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 78314 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 47484
# low 98911
# high 90475
# sl 45109.799999999996
# tp1 47958.840000000004
# tp2 48196.259999999995
# tp3 48433.68
# *************************************************
# high  90475  tp  79097.14 79488.70999999999 79880.28
# TP Active Long
# close ********************** 79880.28
# calculate ***************** 78314 79880.28 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 44980
# low 95633
# high 57347
# sl 42731.0
# tp1 45429.8
# tp2 45654.7
# tp3 45879.6
# *************************************************
# Step:  703       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 79522
# low 22831
# high 40419
# sl 75545.9
# tp1 80317.22
# tp2 80714.82999999999
# tp3 81112.44
# *************************************************
# Step:  704       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 20446
# low 34303
# high 83960
# sl 21468.3
# tp1 20241.54
# tp2 20139.31
# tp3 20037.079999999998
# *************************************************
# Step:  705       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 20446 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 81986
# low 22462
# high 91421
# sl 86085.3
# tp1 81166.14
# tp2 80756.20999999999
# tp3 80346.28
# *************************************************
# high  91421  sl 21468.3
# SL Active SELL
# close ********************** 21468.3
# calculate ***************** 20446 21468.3 short 1 10
# *************** new data received ***************
# -1 prev
# 0 curr
# open 27922
# low 67733
# high 34842
# sl 26525.899999999998
# tp1 28201.22
# tp2 28340.829999999998
# tp3 28480.44
# *************************************************
# Step:  707       Signal is :  1.0
# Open Long Position
# Balance Management
# open ********************** long 27922 1 10
# *************** new data received ***************
# -1 prev
# 1.0 curr
# open 58434
# low 29400
# high 83204
# sl 61355.700000000004
# tp1 57849.659999999996
# tp2 57557.49
# tp3 57265.32
# *************************************************
# high  83204  tp  28201.22 28340.829999999998 28480.44
# TP Active Long
# close ********************** 28480.44
# calculate ***************** 27922 28480.44 long 1 10
# *************** new data received ***************
# 1 prev
# 0 curr
# open 34692
# low 58721
# high 27357
# sl 32957.4
# tp1 35038.92
# tp2 35212.38
# tp3 35385.840000000004
# *************************************************
# Step:  709       Signal is :  1.0
# *************** new data received ***************
# 1 prev
# 0 curr
# open 69499
# low 25578
# high 78422
# sl 72973.95
# tp1 68804.01
# tp2 68456.515
# tp3 68109.02
# *************************************************
# Step:  710       Signal is :  -1.0
# Open Short Position
# Balance Management
# open ********************** short 69499 1 10
# *************** new data received ***************
# 1 prev
# -1.0 curr
# open 89306
# low 80205
# high 81806
# sl 84840.7
# tp1 90199.06
# tp2 90645.59
# tp3 91092.12
# *************************************************
# high  81806  sl 72973.95
# SL Active SELL
# close ********************** 72973.95
# calculate ***************** 69499 72973.95 short 1 10
#      Direction        Sl       Tp1        Tp2       Tp3  Status
# 0          0.0      0.00      0.00      0.000      0.00    None
# 1          1.0  20214.10  21490.78  21597.170  21703.56  profit
# 2         -1.0   1601.25   1509.75   1502.125   1494.50    loss
# 3          1.0  56591.50  60165.70  60463.550  60761.40    loss
# 4         -1.0  88381.65  83331.27  82910.405  82489.54  profit
# ..         ...       ...       ...        ...       ...     ...
# 228       -1.0  17147.55  16167.69  16086.035  16004.38    loss
# 229        1.0  74398.30  79097.14  79488.710  79880.28  profit
# 230       -1.0  21468.30  20241.54  20139.310  20037.08    loss
# 231        1.0  26525.90  28201.22  28340.830  28480.44  profit
# 232       -1.0  72973.95  68804.01  68456.515  68109.02    loss
#
# [233 rows x 6 columns]
